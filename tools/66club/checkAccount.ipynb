# %%
import requests
import execjs
from datetime import datetime

# %%
def checkAccount(random, sign, accNo, token):
    # Yêu cầu OPTIONS
    options_url = "https://api.ngrbet.com/api/webapi/SetWithdrawalBankCard"
    options_headers = {
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "en",
        "Accept-Control-Request-Headers": "ar-real-ip,authorization,content-type",
        "Accept-Control-Request-Method": "POST",
        "Origin": "https://vesovn.cc",
        "Referer": "https://vesovn.cc",
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "cross-site",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    requests.options(options_url, headers=options_headers)

    # Yêu cầu POST
    post_url = "https://api.ngrbet.com/api/webapi/SetWithdrawalBankCard"
    post_headers = {
        "authority": "vn168api.com",
        "accept": "application/json, text/plain, */*",
        "accept-language": "vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5",
        "authorization": "Bearer " + token,
        "content-type": "application/problem+json; charset=UTF-8",
        "origin": "https://vn168.com",
        "referer": "https://vn168.com/",
        "sec-ch-ua": "\"Not.A/Brand\";v=\"8\", \"Chromium\";v=\"114\", \"Google Chrome\";v=\"114\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    post_data = {
        "smsCode": "",
        "ifsccode": "",
        "bankid": 102,
        "beneficiaryname": "Y PHAT NIE",
        "accountno": accNo,
        "email": "",
        "mobileno": "84738173313",
        "bankcitycode": "",
        "bankprovincecode": "",
        "bankbranchaddress": "HCM",
        "type": "",
        "codeType": 6,
        "language": 0,
        "random": random,
        "signature": sign,
        "timestamp": int(datetime.now().timestamp())
    }

    post_response = requests.post(post_url, json=post_data, headers=post_headers).json()

    return post_response

# %%
with open("main.js", "r") as file:
    js_code = file.read()

js_lib = execjs.compile(js_code)

# %%
token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....pyt811paHwFuDYWCQ1kli9IdQ6htmguRQ6M9M7x-Kg8"

# %%
with open('data/numberAccount.txt', 'r') as file:
    accNos = file.readlines()

# %%
for accNo in accNos:
    pre_payload = {
        "smsCode": "",
        "ifsccode": "",
        "bankid": 102,
        "beneficiaryname": "Y PHAT NIE",
        "accountno": accNo.strip(),
        "email": "",
        "mobileno": "84738173313",
        "bankcitycode": "",
        "bankprovincecode": "",
        "bankbranchaddress": "HCM",
        "type": "",
        "codeType": 6,
        "language": 0,
    }

    result = js_lib.call("getSignature", pre_payload)

    response = checkAccount(result[1], result[0], accNo.strip(), token)

    if (response['msgCode'] == 204):
        print("x")
    else:
        print(" ")
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x
# x
# x
# x
#
# x
# x
#
#
# x
# x
# x
# x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x
# x
# x
#
# x
#
# x
#
#
# x
# x
# x
#
#
# x
# x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x
#
#
#
#
#
#
#
#
# x
#
# x
#
# x
#
#
# x
#
# x
#
#
#
# x
#
#
# x
#
#
#
#
#
#
# x
# x
#
#
#
#
# x
#
#
# x
#
# x
# x
#
#
#
# x
# x
# x
#
#
# x
# x
# x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x
# x
# x
# x
# x
# x
#
#
# x
# x
#
# x
#
#
#
# x
# x
# x

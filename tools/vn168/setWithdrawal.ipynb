# %%
import requests
import execjs
from datetime import datetime
import openpyxl
import re
from requests.auth import HTTPProxyAuth
import random
import time

# %%
import random
import string

def generate_random_string(length):
    characters = string.ascii_letters + string.digits
    return ''.join(random.choice(characters) for _ in range(length))

def generate_email_address(user_length=5):
    user = generate_random_string(user_length)
    email = f"user{user}@gmail.com"
    return email

# Tạo 100 địa chỉ email ngẫu nhiên
for _ in range(149):
    email_address = generate_email_address(10)
    print(email_address)
# Out:
# userQ8u9PLfFKf@gmail.com
# user9hx2OkzDqy@gmail.com
# userKuijBaC2Xj@gmail.com
# userUEPJFoGGgo@gmail.com
# userYvkHrlCLDj@gmail.com
# userlaS4M7aloY@gmail.com
# usery8GKk39ENu@gmail.com
# userw7qzjmnss0@gmail.com
# usersgp4W77eOt@gmail.com
# userU44F6xEcNP@gmail.com
# userpfk946rXl2@gmail.com
# user8X2490pXVf@gmail.com
# useraAbPmGIMmN@gmail.com
# user96olGLFJXZ@gmail.com
# userQpk40h3iLK@gmail.com
# userDNIcz1q8ho@gmail.com
# userl7B7uyQBnt@gmail.com
# user2gOvl498ks@gmail.com
# usereP0uxjfk87@gmail.com
# uservi8uXMk0gJ@gmail.com
# user8xUqZNA1Bf@gmail.com
# userslQx7eeycm@gmail.com
# userRjdVgnkY88@gmail.com
# user2piLv8O95k@gmail.com
# user8PsFyZGXeT@gmail.com
# uservxc70MspVh@gmail.com
# userOZYjDzWxZ0@gmail.com
# userbEIW11Q063@gmail.com
# userHnCjpr6CCa@gmail.com
# userLIhfCGOGKf@gmail.com
# userASlMXBUQYB@gmail.com
# userq9Orr2qG9B@gmail.com
# userjO4AFR1nhg@gmail.com
# userwNC7hMPNd3@gmail.com
# userI4xNcEICgR@gmail.com
# userYXCIy44jV2@gmail.com
# userVo91ZJIapw@gmail.com
# user4flIdkcF8e@gmail.com
# userlluvnSnJHE@gmail.com
# userGXeLQgwLXF@gmail.com
# userlTuZY6O7Sj@gmail.com
# userrJOcHpKODt@gmail.com
# userY1QMLtf7z8@gmail.com
# userGDA0WR2S8w@gmail.com
# userbgr0e4ZjQl@gmail.com
# userDf3JXtX6gB@gmail.com
# userGYRjOb4v2L@gmail.com
# user3BLBwak0UC@gmail.com
# userN24CJ38pr0@gmail.com
# userVjC3EKzQ1W@gmail.com
# user73iEpSk1fV@gmail.com
# userIrmOhc98YF@gmail.com
# useruPAkknXcyI@gmail.com
# userwy0BxXxJrM@gmail.com
# userddekrsOGaM@gmail.com
# usereYkZOMEcs0@gmail.com
# userH6rJg3Uiqg@gmail.com
# user3d8eicAGA5@gmail.com
# userlM255mgZ0y@gmail.com
# userKdUx4m1PWD@gmail.com
# userkw2Ff9EEXo@gmail.com
# userrUnUaUB5yy@gmail.com
# user8ZSSaDdlQ3@gmail.com
# userBW2n6PtuZO@gmail.com
# userI6UsOZqvhZ@gmail.com
# userWI7c07BGV0@gmail.com
# userxcZePvYuZa@gmail.com
# user1GtTXYJNRR@gmail.com
# usermLWcngCMeN@gmail.com

# %%
def SetWithdrawal(random, sign, name, accNo, email, phone, address, token, proxy, auth):
    # Yêu cầu OPTIONS
    options_url = "https://vn168api.com/api/webapi/SetWithdrawalBankCard"
    options_headers = {
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "en",
        "Accept-Control-Request-Headers": "ar-real-ip,authorization,content-type",
        "Accept-Control-Request-Method": "POST",
        "Origin": "https://vn168-1.com",
        "Referer": "https://vn168-1.com",
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "cross-site",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    requests.options(options_url, headers=options_headers, proxies=proxy, auth=auth)

    # Yêu cầu POST
    post_url = "https://vn168api.com/api/webapi/SetWithdrawalBankCard"
    post_headers = {
        "authority": "vn168api.com",
        "accept": "application/json, text/plain, */*",
        "accept-language": "vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5",
        "authorization": "Bearer " + token,
        "content-type": "application/problem+json; charset=UTF-8",
        "origin": "https://vn168.com",
        "referer": "https://vn168.com/",
        "sec-ch-ua": "\"Not.A/Brand\";v=\"8\", \"Chromium\";v=\"114\", \"Google Chrome\";v=\"114\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    post_data = {
        "smsCode": "",
        "ifsccode": "",
        "bankid": 102,
        "beneficiaryname": name,
        "accountno": accNo,
        "email": email,
        "mobileno": "84" + phone,
        "bankcitycode": "",
        "bankprovincecode": "",
        "bankbranchaddress": address,
        "type": "",
        "codeType": 6,
        "language": 2,
        "random": random,
        "signature": sign,
        "timestamp": int(datetime.now().timestamp())
    }

    post_response = requests.post(post_url, json=post_data, headers=post_headers, proxies=proxy, auth=auth).json()

    return post_response

# %%
def GetToken(phone, random, sign, proxy, auth):
    # Yêu cầu OPTIONS
    options_url = "https://vn168api.com/api/webapi/Login"
    options_headers = {
        "authority": "vn168api.com",
        "accept": "*/*",
        "accept-language": "vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5",
        "access-control-request-headers": "authorization,content-type",
        "access-control-request-method": "POST",
        "origin": "https://vn168.com",
        "referer": "https://vn168.com/",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    requests.options(options_url, headers=options_headers, proxies=proxy, auth=auth)

    # Yêu cầu POST
    post_url = "https://vn168api.com/api/webapi/Login"
    post_headers = {
        "accept": "application/json, text/plain, */*",
        "accept-language": "vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5",
        "authorization": "Bearer",
        "content-type": "application/problem+json; charset=UTF-8",
        "sec-ch-ua": "\"Not.A/Brand\";v=\"8\", \"Chromium\";v=\"114\", \"Google Chrome\";v=\"114\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site"
    }
    post_data = {
        "language": 2,
        "logintype": "mobile",
        "phonetype": -1,
        "pwd": "GiaMinh123",
        "random": random,
        "signature": sign,
        "timestamp": int(datetime.now().timestamp()),
        "username": "84" + phone
    }
    post_response = requests.post(post_url, headers=post_headers, json=post_data, proxies=proxy, auth=auth).json()

    return post_response['data']['token']

# %%
with open("main.js", "r") as file:
    js_code = file.read()

js_lib = execjs.compile(js_code)

# %%
wb = openpyxl.load_workbook('./data/stk.xlsx')

# %%
with open('data/signature.txt', 'r') as file:
    auth = file.read()

random_values = re.findall(r'"random":"(.*?)"', auth)
signature_values = re.findall(r'"signature":"(.*?)"', auth)

# %%
with open('../proxy.txt', 'r') as file:
    listProxy = file.readlines()

# %%
sheet = wb['Sheet1']
g_all = sheet.values
listInfos = list(g_all)
listInfos = listInfos[1:]
for info, randoms, sign in zip(listInfos, random_values, signature_values):
    proxyRaw = random.choice(listProxy).strip().split(":")
    ip = proxyRaw[0]
    port = proxyRaw[1]
    user = proxyRaw[2]
    pwd = proxyRaw[3]
    proxy = {
    'http': 'http://' + ip + ":" + port,
    'https': 'http://' + ip + ":" + port
    }

    auth = HTTPProxyAuth(user, pwd)
    pre_payload = {
        "smsCode": "",
        "ifsccode": "",
        "bankid": 102,
        "beneficiaryname": info[1],
        "accountno": info[2],
        "email": info[4],
        "mobileno": "84" + info[3],
        "bankcitycode": "",
        "bankprovincecode": "",
        "bankbranchaddress": info[5],
        "type": "",
        "codeType": 6,
        "language": 2,
    }
    try:
        token = GetToken(info[3], randoms, sign, proxy, auth)
    except:
        print(info[3])
        continue
    result = js_lib.call("getSignature", pre_payload)
    response = SetWithdrawal(result[1], result[0], info[1], info[2], info[4], info[3], info[5], token, proxy, auth)
    print(response)
    time.sleep(random.randint(180,300))
# Out:
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 15:33:28'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 15:36:43'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 15:40:50'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 15:45:49'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 15:49:56'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 15:54:57'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 15:59:35'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:03:46'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:07:13'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:10:18'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:13:50'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:17:00'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:21:13'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:24:48'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:27:53'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:31:04'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:34:41'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:38:12'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:41:54'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:46:41'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:50:06'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:54:44'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 16:58:40'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:03:01'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:06:44'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:11:36'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:14:49'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:19:40'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:23:50'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:27:26'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:31:25'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:34:56'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:38:46'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:43:41'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:47:43'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:52:19'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 17:56:33'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:00:10'}
# {'code': 1, 'msg': 'The bank number has been occupied', 'msgCode': 204, 'serviceNowTime': '2024-03-01 18:04:13'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:07:53'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:11:15'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:15:43'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:20:17'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:23:48'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:27:39'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:31:31'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:36:24'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:39:30'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:42:44'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:45:47'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:49:42'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:53:21'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-03-01 18:57:55'}

# %%
import requests
import execjs
from datetime import datetime
import openpyxl
import re
import random
from requests.auth import HTTPProxyAuth
import time

# %%
def SetWithdrawal(random, sign, name, accNo, email, phone, address, token, proxy, auth):
    # Yêu cầu OPTIONS
    options_url = "https://vn168api.com/api/webapi/SetWithdrawalBankCard"
    options_headers = {
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "en",
        "Accept-Control-Request-Headers": "ar-real-ip,authorization,content-type",
        "Accept-Control-Request-Method": "POST",
        "Origin": "https://vn168-1.com",
        "Referer": "https://vn168-1.com",
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "cross-site",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    requests.options(options_url, headers=options_headers, proxies=proxy, auth=auth)

    # Yêu cầu POST
    post_url = "https://vn168api.com/api/webapi/SetWithdrawalBankCard"
    post_headers = {
        "authority": "vn168api.com",
        "accept": "application/json, text/plain, */*",
        "accept-language": "vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5",
        "authorization": "Bearer " + token,
        "content-type": "application/problem+json; charset=UTF-8",
        "origin": "https://vn168.com",
        "referer": "https://vn168.com/",
        "sec-ch-ua": "\"Not.A/Brand\";v=\"8\", \"Chromium\";v=\"114\", \"Google Chrome\";v=\"114\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    post_data = {
        "smsCode": "",
        "ifsccode": "",
        "bankid": 102,
        "beneficiaryname": name,
        "accountno": accNo,
        "email": email,
        "mobileno": "84" + phone,
        "bankcitycode": "",
        "bankprovincecode": "",
        "bankbranchaddress": address,
        "type": "",
        "codeType": 6,
        "language": 2,
        "random": random,
        "signature": sign,
        "timestamp": int(datetime.now().timestamp())
    }

    post_response = requests.post(post_url, json=post_data, headers=post_headers, proxies=proxy, auth=auth).json()

    return post_response

# %%
def GetToken(phone, random, sign, proxy, auth):
    # Yêu cầu OPTIONS
    options_url = "https://vn168api.com/api/webapi/Login"
    options_headers = {
        "authority": "vn168api.com",
        "accept": "*/*",
        "accept-language": "vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5",
        "access-control-request-headers": "authorization,content-type",
        "access-control-request-method": "POST",
        "origin": "https://vn168.com",
        "referer": "https://vn168.com/",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    requests.options(options_url, headers=options_headers, proxies=proxy, auth=auth)

    # Yêu cầu POST
    post_url = "https://vn168api.com/api/webapi/Login"
    post_headers = {
        "accept": "application/json, text/plain, */*",
        "accept-language": "vi-VN,vi;q=0.9,fr-FR;q=0.8,fr;q=0.7,en-US;q=0.6,en;q=0.5",
        "authorization": "Bearer",
        "content-type": "application/problem+json; charset=UTF-8",
        "sec-ch-ua": "\"Not.A/Brand\";v=\"8\", \"Chromium\";v=\"114\", \"Google Chrome\";v=\"114\"",
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": "\"Windows\"",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site"
    }
    post_data = {
        "language": 2,
        "logintype": "mobile",
        "phonetype": -1,
        "pwd": "GiaMinh123",
        "random": random,
        "signature": sign,
        "timestamp": int(datetime.now().timestamp()),
        "username": "84" + phone
    }
    post_response = requests.post(post_url, headers=post_headers, json=post_data, proxies=proxy, auth=auth).json()

    return post_response['data']['token']

# %%
with open("main.js", "r") as file:
    js_code = file.read()

js_lib = execjs.compile(js_code)

# %%
wb = openpyxl.load_workbook('./data/stk.xlsx')

# %%
with open('data/signature.txt', 'r') as file:
    auth = file.read()

random_values = re.findall(r'"random":"(.*?)"', auth)
signature_values = re.findall(r'"signature":"(.*?)"', auth)

# %%
with open('../proxy.txt', 'r') as file:
    listProxy = file.readlines()

# %%
sheet = wb['Sheet1']
g_all = sheet.values
listInfos = list(g_all)
listInfos = listInfos[1:]
for info, randoms, sign in zip(listInfos, random_values, signature_values):
    proxyRaw = random.choice(listProxy).strip().split(":")
    ip = proxyRaw[0]
    port = proxyRaw[1]
    user = proxyRaw[2]
    pwd = proxyRaw[3]
    proxy = {
    'http': 'http://' + ip + ":" + port,
    'https': 'http://' + ip + ":" + port
    }

    auth = HTTPProxyAuth(user, pwd)
    pre_payload = {
        "smsCode": "",
        "ifsccode": "",
        "bankid": 102,
        "beneficiaryname": info[1],
        "accountno": info[2],
        "email": info[4],
        "mobileno": "84" + info[3],
        "bankcitycode": "",
        "bankprovincecode": "",
        "bankbranchaddress": info[5],
        "type": "",
        "codeType": 6,
        "language": 2,
    }
    try:
        token = GetToken(info[3], randoms, sign, proxy, auth)
    except:
        print(info[3])
        continue
    result = js_lib.call("getSignature", pre_payload)
    response = SetWithdrawal(result[1], result[0], info[1], info[2], info[4], info[3], info[5], token, proxy, auth)
    print(response)
    time.sleep(random.randint(5,10))
# Out:
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:08:02'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:08:13'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:08:21'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:08:34'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:08:48'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:08:58'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:09:14'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:09:25'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:09:36'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:09:49'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:10:03'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:10:16'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:10:28'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:10:39'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:10:48'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:11:00'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:11:12'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:11:24'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:11:38'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:11:51'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:12:02'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:12:13'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:12:27'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:12:37'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:12:49'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:13:03'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:13:13'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:13:26'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:13:35'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:13:47'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:14:01'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:14:10'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:14:25'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:14:38'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:14:50'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:15:02'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:15:12'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:15:24'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:15:37'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:15:51'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:16:03'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:16:14'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:16:26'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:16:39'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:16:48'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:16:58'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:17:12'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:17:21'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:17:33'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:17:43'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:17:52'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:18:05'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:18:15'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:18:24'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:18:35'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:18:48'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:19:00'}
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:19:13'}
# 978454691
# {'code': 0, 'msg': 'Succeed', 'msgCode': 0, 'serviceNowTime': '2024-01-14 01:19:27'}
